# %% [markdown]
# # 天池新闻推荐 - 统一方案运行
#
# 运行 `SolutionUnified`：4 路召回融合 + LightGBM Ranker 排序

# %%
import sys
sys.path.insert(0, '..')

from solutions.solution_unified import SolutionUnified

# %%
pipeline = SolutionUnified()
metrics = pipeline.run()

# %%
print('\n=== Final Metrics ===')
for k, v in metrics.items():
    print(f'{k}: {v:.4f}')
